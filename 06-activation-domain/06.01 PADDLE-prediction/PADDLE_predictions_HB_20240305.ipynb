# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import tensorflow as tf # tested on version 2.2.0
import matplotlib
matplotlib.rcParams['figure.dpi'] = 100
matplotlib.rcParams['font.sans-serif'] = 'Arial'
from matplotlib import pyplot as plt
from Bio import SeqIO
import paddle

# Set Numpy to display floats with 3 decimal places
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# Out:
# 2024-03-14 22:17:56.974839: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # PADDLE

# %%
########
# Run predictions using PADDLE. This network requires predicted secondary
# structure (from PSIPRED) and predicted disorder (from IUPRED2, in both the
# short and long modes) as input in addition to the protein sequence. This
# model is the most accurate and should be used for predicted ADs in wild-type
# proteins.
########

# Load PADDLE models. There are 10 in total, and their individual predictions
# are averaged to obtain the final result.
pad = paddle.PADDLE()
# Out:
# Loading model split 1 of 10
# Loading model split 2 of 10
# Loading model split 3 of 10
# Loading model split 4 of 10
# Loading model split 5 of 10
# Loading model split 6 of 10
# Loading model split 7 of 10
# Loading model split 8 of 10
# Loading model split 9 of 10
# Loading model split 10 of 10

# %% [markdown]
# ## ScerPho4

# %%
# Load protein sequence
name = "Scer"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20231004-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step

# %% [markdown]
# ## SmikPho4

# %%
# Load protein sequence
name = "Smik"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step

# %% [markdown]
# ## SparPho4

# %%
# Load protein sequence
name = "Spar"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# 9/9 [==============================] - 0s 6ms/step

# %% [markdown]
# ## CglaPho4

# %%
# Load protein sequence
name = "Cgla"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20231004-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step

# %% [markdown]
# ## CbraPho4

# %%
# Load protein sequence
name = "Cbra"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 8ms/step

# %% [markdown]
# ## CnivPho4

# %%
# Load protein sequence
name = "Cniv"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 7ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step
# 14/14 [==============================] - 0s 6ms/step

# %% [markdown]
# ## NdelPho4

# %%
# Load protein sequence
name = "Ndel"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 13/13 [==============================] - 0s 8ms/step
# 13/13 [==============================] - 0s 7ms/step
# 13/13 [==============================] - 0s 6ms/step
# 13/13 [==============================] - 0s 6ms/step
# 13/13 [==============================] - 0s 7ms/step
# 13/13 [==============================] - 0s 6ms/step
# 13/13 [==============================] - 0s 7ms/step
# 13/13 [==============================] - 0s 7ms/step
# 13/13 [==============================] - 0s 7ms/step
# 13/13 [==============================] - 0s 7ms/step

# %% [markdown]
# ## NbacPho4

# %%
# Load protein sequence
name = "Nbac"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 16/16 [==============================] - 0s 7ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step
# 16/16 [==============================] - 0s 6ms/step

# %% [markdown]
# ## NcasPho4

# %%
# Load protein sequence
name = "Ncas"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 7ms/step
# 15/15 [==============================] - 0s 7ms/step
# 15/15 [==============================] - 0s 7ms/step

# %% [markdown]
# ## KlacPho4

# %%
# Load protein sequence
name = "Klac"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 20/20 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 7ms/step
# 20/20 [==============================] - 0s 7ms/step
# 20/20 [==============================] - 0s 14ms/step
# 20/20 [==============================] - 0s 8ms/step
# 20/20 [==============================] - 0s 7ms/step
# 20/20 [==============================] - 0s 7ms/step
# 20/20 [==============================] - 0s 6ms/step

# %% [markdown]
# ## LkluPho4

# %%
# Load protein sequence
name = "Lklu"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step

# %% [markdown]
# ## LwalPho4

# %%
# Load protein sequence
name = "Lwal"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step

# %% [markdown]
# ## CalbPho4

# %%
# Load protein sequence
name = "Calb"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 5ms/step
# 19/19 [==============================] - 0s 6ms/step

# %% [markdown]
# ## DhanPho4

# %%
# Load protein sequence
name = "Dhan"
record = SeqIO.read('data/fasta/' + name + 'Pho4.fa', 'fasta')
prot = str(record.seq).strip("*")


# Load pre-computed secondary structure predicted by PSIPRED V4.
# When predicting across a large number of sequences, PSIPRED can be run
# without using BLAST, this speeds up secondary structure prediction.
seq, helix, coil = paddle.read_ss2('data/psipred/20240316-' + name + 'Pho4.ss2')
assert prot == seq

# Load pre-computed disorder predicted by IUPRED2, in both
# the short and long modes.
prot, dis_short = paddle.read_iupred('data/iupred2/' + name + 'Pho4-short.dis')
assert prot == seq
prot, dis_long = paddle.read_iupred('data/iupred2/' + name + 'Pho4-long.dis')
assert prot == seq

# Run predictions on all 53 amino acid long tiles across the protein.
# This function requires matching protein sequence and secondary structure scores.
# Returns a Numpy array of size (protein_length-52) which gives the
# predicted activation Z-score for the 53aa tiles starting at positions
# 1, 2, 3, ..., protein_length-52.
# High-strength ADs can be called by finding >=5 consecutive positions with Z-score > 6.
# Medium-strength ADs can be called by finding >=5 consecutive positions with Z-score > 4.
preds = pad.predict_protein(prot, helix, coil, dis_short, dis_long)

# Plot predicted Z-scores based on the tiles' position in the protein.
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(len(preds)) + (53+1)/2, preds)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted Z-score')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.savefig('output/img/20240316' + name + 'Pho4-PADDLE-z-score.png', transparent = True, dpi = 300)
plt.show()

# Z-scores can be converted to fold-activation. This is only useful
# as a rough reference for activation in S. cerevisiae, as the
# fold-activation will vary between different experimental conditions.
pred_act = paddle.score2act(preds)

plt.figure(figsize=(8,2.5))
plt.semilogy(np.arange(len(pred_act)) + (53+1)/2, pred_act)
plt.xlabel('Center position of 53aa tile')
plt.ylabel('Predicted activation')
plt.title(name + 'Pho4')
plt.xlim(0,len(prot))
plt.show()

# Export both the Z-score and the fold-activation data
pred_df = pd.DataFrame({'Pos': np.arange(len(pred_act)) + (53+1)/2, 'Z_score': preds, 'Fold': pred_act})
pred_df.to_csv('output/20240316-' + name + 'Pho4-PADDLE-prediction.csv', index = False)
# Out:
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step
# 14/14 [==============================] - 0s 5ms/step

# %% [markdown]
# # PADDLE-noSS (fast)

# %%
########
# Run predictions using PADDLE-noSS. This network does not need predicted
# structure scores from PSIPRED and IUPRED2 and can therefore run very fast, and
# is nearly as accurate as PADDLE (with structure input). This model can be used
# when running predictions on a large number of mutant sequences, for example.
########

# Load PADDLE-noSS models. There are 10 in total, and their individual predictions
# are averaged to obtain the final result.
pad_noSS = paddle.PADDLE_noSS()
# Out:
# Loading model split 1 of 10
# Loading model split 2 of 10
# Loading model split 3 of 10
# Loading model split 4 of 10
# Loading model split 5 of 10
# Loading model split 6 of 10
# Loading model split 7 of 10
# Loading model split 8 of 10
# Loading model split 9 of 10
# Loading model split 10 of 10

# %%
# Within an AD from Arg81, let's predict the effect on activation
# of mutating each residue to alanine one at a time.
with open('data/Arg81.fa', 'r') as f:
    f.readline()
    prot = f.readline().strip()
AD = prot[200 : 253]

# construct list of scanning alanine mutant sequences
muts = []
for i in range(len(AD)):
    mut = list(AD)
    mut[i] = 'A'
    muts.append(''.join(mut))
    
# Run predictions. This function takes a list of 53aa protein sequences (strings)
# as input and returns an array of the same size of predicted activation Z-scores.
# This function can also take a single 53aa sequence as input, but running many
# sequences at once in batch will be faster than individually.
preds = pad_noSS.predict(muts)

# Plot the results based on the amino acid position that was mutated to alanine.
plt.figure(figsize=(8,2.5))
plt.plot(preds)
plt.xticks(np.arange(len(AD)), list(AD))
plt.xlim(-1, len(AD))
plt.title('Arg81: 201-253')
plt.xlabel('Residue mutated to alanine')
plt.ylabel('Predicted Z-score')
plt.show()
# Out:
# 2/2 [==============================] - 1s 10ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step

# %%
# Within an AD from Arg81, let's predict the effect on activation
# of mutating each residue to alanine one at a time.
with open('data/Arg81.fa', 'r') as f:
    f.readline()
    prot = f.readline().strip()
AD = prot[200 : 253]

# construct list of scanning alanine mutant sequences
muts = []
for i in range(len(AD)):
    mut = list(AD)
    mut[i] = 'A'
    muts.append(''.join(mut))
    
# Run predictions. This function takes a list of 53aa protein sequences (strings)
# as input and returns an array of the same size of predicted activation Z-scores.
# This function can also take a single 53aa sequence as input, but running many
# sequences at once in batch will be faster than individually.
preds = pad_noSS.predict(muts)

# Plot the results based on the amino acid position that was mutated to alanine.
plt.figure(figsize=(8,2.5))
plt.plot(preds)
plt.xticks(np.arange(len(AD)), list(AD))
plt.xlim(-1, len(AD))
plt.title('Arg81: 201-253')
plt.xlabel('Residue mutated to alanine')
plt.ylabel('Predicted Z-score')
plt.show()

# %%
# Within an AD from Arg81, let's find core AD regions by predicting
# the activation Z-scores of 13aa tiles. To predict on sequences
# shorter than 53aa, we need to embed them inside 'neutral' sequences
# (i.e. with no intrinsic activation capacity)
AD_start = 194
AD_stop = 256

# Generate neutral background sequences by randomly sampling from AGSTNQV
# residues. To minimize the effect of the background sequence, it's good
# to use many of them and average the results.
np.random.seed(42)
bg_prots = [''.join(np.random.choice(list('AGSTNQV'), size=53)) for _ in range(10)]

# Run predictions. This takes a list of protein sequences which can be 53aa or shorter
# and a list of background sequences to embed in.
preds = pad_noSS.predict_subsequences([prot[i:i+13] for i in range(AD_start, AD_stop)], bg_prots)

# Plot the results based on the 13aa tiles' position in the protein
plt.figure(figsize=(8,2.5))
plt.plot(np.arange(AD_start, AD_stop) + (13+1)/2, preds)
plt.xlabel('Center position of 13aa tile')
plt.ylabel('Predicted Z-score')
plt.title('Arg81 AD')
plt.show()
